# %% [markdown]
# # Lets go babYYY!

# %%
# Import everything we need
import json
import requests
import datetime
import pytz
import secrets #contains the notion token, the notion database ID, and the canvas token.

# %%
# Have a list of all classes and their corresponding course ids so you can change what we're working
# with at the moment
course_ids = {
  "INFO 310": "1479924",
  "INFO 200": "1479903",
  "ENVIR 239": "1478724",
  "INFO 330": "1479933",
  "INFO 415": "1516805",
  "INFO 340": "1516756",
  "BIME 435": "1514384",
  "INFO 200 Wi 2022": "1516711", #Wi 2022
}

## have a list of all the emojis you want to attribute to each class
course_emojis = {
  "1479924": "🔐", #INFO 310 
  "1479903": "💛", #INFO 200
  "1478724": "♻️",  #ENVIR 239
  "1479933": "🗄",    #INFO 330
  "1516805": "🛡",   #INFO 415
  "1516756": "🕷", #INFO 340
  "1514384": "🏥", #BIME 435
  "1516711": "👽" #INFO 200 Wi 2022
}

# %%
# Chose the current course we're working with
current_course_name = input("Course: ")
current_course_id = course_ids[current_course_name]

# %%
# Create the necessary url and headers for notion
notion_base_url = "https://api.notion.com/v1/pages"
notion_headers = {
    "Authorization": "Bearer " + secrets.notion_token,
    "Content-Type": "application/json",
    "Notion-Version": "2021-08-16"
}

# Create the necessary url and headers for canvas
canvas_base = "https://canvas.uw.edu/api/v1/courses/"
canvas_assGr_URL = canvas_base + current_course_id + "/assignment_groups"
canvas_header = {
    "Authorization": "Bearer " + secrets.canvas_token
}

# %%
# Get the project groups from canvas
response = requests.get(canvas_assGr_URL, headers=canvas_header)

# Convert it into readable json format
proj_groups = response.json()

print(proj_groups)
# Out:
# [{'id': 1584871, 'name': 'Module Activities', 'position': 1, 'group_weight': 0.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}, {'id': 1692136, 'name': 'In-Class Activities', 'position': 2, 'group_weight': 10.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}, {'id': 1692141, 'name': 'Labs', 'position': 3, 'group_weight': 10.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}, {'id': 1692140, 'name': 'Reading Discussions', 'position': 4, 'group_weight': 40.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}, {'id': 1692139, 'name': 'Projects', 'position': 5, 'group_weight': 40.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}, {'id': 1694656, 'name': 'Imported Assignments', 'position': 6, 'group_weight': 0.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}]

# %%
#  For each project group get all the assignments, clean up the data, and put it in a page
for i in range(0, len(proj_groups)):
    # get the id for the assignment group we're currently looking at
    assGrID = str(proj_groups[i]["id"])

    # make the URL to get the assignments in that group
    canvas_ass_URL = canvas_assGr_URL + "/" + assGrID + "/assignments"

    print(canvas_ass_URL)

    # get the assignments in that project group from canvas
    response = requests.get(canvas_ass_URL, headers=canvas_header)

    # Convert it into readable json format
    assignments = response.json()

    # For each assignment clean up the data and pop it into canvas
    for k in range(len(assignments)):

        # Pop off the assignment we need right now
        current = assignments[k]
        
        # Format part of the assignment URL we need to make it accessible as a UW student
        better_URL = current["html_url"].replace("https://canvas.instructure.com", "https://canvas.uw.edu")

        # Format the date to be equipped to timezone change
        if (current["due_at"] is None):
            better_date = ""
        else:
            # First make the assignment due date into a datetime object
            dt = datetime.datetime.strptime(current["due_at"], "%Y-%m-%dT%H:%M:%SZ")
            # Then make sure the timezone of the datetime object is UTC
            dt_UTC = pytz.utc.localize(dt)
            # Then switch the timezone to where you are
            dt_pst = dt_UTC.astimezone(pytz.timezone("America/Los_Angeles")) 
            # Then make sure the date we put into the page is in ISO format
            better_date = dt_pst.isoformat()

        # Create a new dictionary that will populate the new notion page of this assignment
        pageData = {
            "parent": { 
                "database_id": secrets.notion_database_id
            },
            "icon": {
                "type": "emoji",
                "emoji": course_emojis[current_course_id]
            },
            "properties": {
                "Title": {
                    "title": [
                        {
                            "text": {
                                "content": current["name"]
                            }
                        }
                    ]
                },
                "Class": {
                    "select": {
                        "name": current_course_name
                    }
                },
                "Due Date": {
                    "date": {
                        "start": better_date
                    }
                },
                "URL" : {
                    "url": better_URL
                },
                "Type": {
                    "select": {
                        "name": proj_groups[i]["name"]
                    }
                },
                "Completed" : {
                    "select": {
                        "name": "Not Started"
                    }
                },
                "Starting early": {
                    "checkbox": False
                }
            }
        }

        # Convert the new dictionary pageData to json for sending
        data = json.dumps(pageData)

        # Send the new page out to notion
        res = requests.request("POST", notion_base_url, headers=notion_headers, data=data)

        # Troubleshoot helpers
        print(res.status_code)
        print(res.text)
# Out:
# https://canvas.uw.edu/api/v1/courses/1516711/assignment_groups/1584871/assignments
# 400
# {"object":"error","status":400,"code":"validation_error","message":"body failed validation: body.properties.Due Date.date.start should be a valid ISO 8601 date string, instead was `\"\"`."}
# https://canvas.uw.edu/api/v1/courses/1516711/assignment_groups/1692136/assignments
# 200
# {"object":"page","id":"3b508af4-0cdc-4798-ab73-4d9a6f58994c","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"3c882a61-f339-4118-ae17-cf4ebf2653ce","name":"In-Class Activities","color":"red"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-03T17:30:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6940312"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 1 Activity","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 1 Activity","href":null}]}},"url":"https://www.notion.so/Module-1-Activity-3b508af40cdc4798ab734d9a6f58994c"}
# 200
# {"object":"page","id":"d0854d39-c5bb-4aea-93fd-73bb94efe6bc","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"3c882a61-f339-4118-ae17-cf4ebf2653ce","name":"In-Class Activities","color":"red"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-10T17:30:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6940902"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 2 Activity","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 2 Activity","href":null}]}},"url":"https://www.notion.so/Module-2-Activity-d0854d39c5bb4aea93fd73bb94efe6bc"}
# 200
# {"object":"page","id":"1a8f57bd-cb60-4d00-8165-cd86bb1c7494","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"3c882a61-f339-4118-ae17-cf4ebf2653ce","name":"In-Class Activities","color":"red"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-19T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942213"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 3 Activity","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 3 Activity","href":null}]}},"url":"https://www.notion.so/Module-3-Activity-1a8f57bdcb604d008165cd86bb1c7494"}
# 200
# {"object":"page","id":"6af43406-841f-47af-a13e-1aa89f13ac63","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"3c882a61-f339-4118-ae17-cf4ebf2653ce","name":"In-Class Activities","color":"red"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-24T17:30:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942216"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 4 Activity","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 4 Activity","href":null}]}},"url":"https://www.notion.so/Module-4-Activity-6af43406841f47afa13e1aa89f13ac63"}
# 200
# {"object":"page","id":"d8816dd9-b013-4151-b0a7-faa3bc81116f","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"3c882a61-f339-4118-ae17-cf4ebf2653ce","name":"In-Class Activities","color":"red"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-31T17:30:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942219"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 5 Activity","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 5 Activity","href":null}]}},"url":"https://www.notion.so/Module-5-Activity-d8816dd9b0134151b0a7faa3bc81116f"}
# 200
# {"object":"page","id":"dc6e06a4-9d94-4408-a8ed-85a1d84acc44","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"3c882a61-f339-4118-ae17-cf4ebf2653ce","name":"In-Class Activities","color":"red"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-07T17:30:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942224"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 6 Activity","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 6 Activity","href":null}]}},"url":"https://www.notion.so/Module-6-Activity-dc6e06a49d944408a8ed85a1d84acc44"}
# 200
# {"object":"page","id":"e51226a2-fc68-41b1-9416-76c2a9c2fb4d","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"3c882a61-f339-4118-ae17-cf4ebf2653ce","name":"In-Class Activities","color":"red"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-14T17:30:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942227"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 7 Activity","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 7 Activity","href":null}]}},"url":"https://www.notion.so/Module-7-Activity-e51226a2fc6841b1941676c2a9c2fb4d"}
# 200
# {"object":"page","id":"cbbd78f2-8cc4-446a-b7c3-97deb22c05d5","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"3c882a61-f339-4118-ae17-cf4ebf2653ce","name":"In-Class Activities","color":"red"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-21T17:30:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942233"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 8 Activity","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 8 Activity","href":null}]}},"url":"https://www.notion.so/Module-8-Activity-cbbd78f28cc4446ab7c397deb22c05d5"}
# 200
# {"object":"page","id":"cf527d1f-c584-411c-8a15-92eee50c212f","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"3c882a61-f339-4118-ae17-cf4ebf2653ce","name":"In-Class Activities","color":"red"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-28T17:30:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942236"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 9 Activity","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 9 Activity","href":null}]}},"url":"https://www.notion.so/Module-9-Activity-cf527d1fc584411c8a1592eee50c212f"}
# https://canvas.uw.edu/api/v1/courses/1516711/assignment_groups/1692141/assignments
# 200
# {"object":"page","id":"12f62e4e-548a-4e4a-b918-1983bd18e214","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-04T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6940927"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 1 Lab","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 1 Lab","href":null}]}},"url":"https://www.notion.so/Module-1-Lab-12f62e4e548a4e4ab9181983bd18e214"}
# 200
# {"object":"page","id":"cb872a85-b14e-47d3-b5b4-80fe695e8029","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-11T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942211"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 2 Lab","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 2 Lab","href":null}]}},"url":"https://www.notion.so/Module-2-Lab-cb872a85b14e47d3b5b480fe695e8029"}
# 200
# {"object":"page","id":"d5ca16bc-f823-4b7a-b573-323f218b410a","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-18T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942214"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 3 Lab","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 3 Lab","href":null}]}},"url":"https://www.notion.so/Module-3-Lab-d5ca16bcf8234b7ab573323f218b410a"}
# 200
# {"object":"page","id":"c7692e89-2cf9-4e1a-b3b3-f508c117df04","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-25T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942217"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 4 Lab","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 4 Lab","href":null}]}},"url":"https://www.notion.so/Module-4-Lab-c7692e892cf94e1ab3b3f508c117df04"}
# 200
# {"object":"page","id":"bdd2bc68-3d36-464d-a096-a235278c47ca","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-01T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942220"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 5 Lab","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 5 Lab","href":null}]}},"url":"https://www.notion.so/Module-5-Lab-bdd2bc683d36464da096a235278c47ca"}
# 200
# {"object":"page","id":"04b1f711-eb77-4fb5-8800-0cfb1e7c5e1c","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-08T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942225"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 6 Lab","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 6 Lab","href":null}]}},"url":"https://www.notion.so/Module-6-Lab-04b1f711eb774fb588000cfb1e7c5e1c"}
# 200
# {"object":"page","id":"83a26322-15d3-4086-a880-36be3ffbde76","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-15T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942228"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 7 Lab","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 7 Lab","href":null}]}},"url":"https://www.notion.so/Module-7-Lab-83a2632215d34086a88036be3ffbde76"}
# 200
# {"object":"page","id":"01fddd83-89b4-4deb-a8d6-db7a254d1e08","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-22T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942234"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 8 Lab","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 8 Lab","href":null}]}},"url":"https://www.notion.so/Module-8-Lab-01fddd8389b44deba8d6db7a254d1e08"}
# 200
# {"object":"page","id":"aec916a0-3893-4f60-8720-43596acb60f9","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-03-01T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942237"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 9 Lab","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 9 Lab","href":null}]}},"url":"https://www.notion.so/Module-9-Lab-aec916a038934f60872043596acb60f9"}
# 200
# {"object":"page","id":"d669ac0b-70ce-4614-bc21-d3240955567e","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-03-08T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942240"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 10 Lab","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 10 Lab","href":null}]}},"url":"https://www.notion.so/Module-10-Lab-d669ac0b70ce4614bc21d3240955567e"}
# https://canvas.uw.edu/api/v1/courses/1516711/assignment_groups/1692140/assignments
# 200
# {"object":"page","id":"3b55b74a-508d-4deb-8061-1eee967d8450","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"b2c6945d-5214-4018-8ee2-f09b25447c8a","name":"Reading Discussions","color":"gray"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-05T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6940933"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 1 Reading Discussion","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 1 Reading Discussion","href":null}]}},"url":"https://www.notion.so/Module-1-Reading-Discussion-3b55b74a508d4deb80611eee967d8450"}
# 200
# {"object":"page","id":"6acef93d-e881-465a-81e8-2a0d1fc197ad","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"b2c6945d-5214-4018-8ee2-f09b25447c8a","name":"Reading Discussions","color":"gray"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-10T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942212"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 2 Reading Discussion","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 2 Reading Discussion","href":null}]}},"url":"https://www.notion.so/Module-2-Reading-Discussion-6acef93de881465a81e82a0d1fc197ad"}
# 200
# {"object":"page","id":"27bdff3e-ba00-40ed-8325-19cfafe8fdc2","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"b2c6945d-5214-4018-8ee2-f09b25447c8a","name":"Reading Discussions","color":"gray"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-18T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942215"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 3 Reading Discussion","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 3 Reading Discussion","href":null}]}},"url":"https://www.notion.so/Module-3-Reading-Discussion-27bdff3eba0040ed832519cfafe8fdc2"}
# 200
# {"object":"page","id":"cb90030b-306e-476a-80d9-f295d5c8e326","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"b2c6945d-5214-4018-8ee2-f09b25447c8a","name":"Reading Discussions","color":"gray"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-24T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942218"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 4 Reading Discussion","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 4 Reading Discussion","href":null}]}},"url":"https://www.notion.so/Module-4-Reading-Discussion-cb90030b306e476a80d9f295d5c8e326"}
# 200
# {"object":"page","id":"78d3719a-5466-4a01-b05b-f8bc5df9302e","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"b2c6945d-5214-4018-8ee2-f09b25447c8a","name":"Reading Discussions","color":"gray"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-31T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942221"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 5 Reading Discussion","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 5 Reading Discussion","href":null}]}},"url":"https://www.notion.so/Module-5-Reading-Discussion-78d3719a54664a01b05bf8bc5df9302e"}
# 200
# {"object":"page","id":"7248e6b9-7655-4d74-b693-c86b2a88dfb1","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"b2c6945d-5214-4018-8ee2-f09b25447c8a","name":"Reading Discussions","color":"gray"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-07T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942226"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 6 Reading Discussion","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 6 Reading Discussion","href":null}]}},"url":"https://www.notion.so/Module-6-Reading-Discussion-7248e6b976554d74b693c86b2a88dfb1"}
# 200
# {"object":"page","id":"f5173c0a-7e07-4323-9f35-f0b11af3fdfa","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"b2c6945d-5214-4018-8ee2-f09b25447c8a","name":"Reading Discussions","color":"gray"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-14T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942229"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 7 Reading Discussion","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 7 Reading Discussion","href":null}]}},"url":"https://www.notion.so/Module-7-Reading-Discussion-f5173c0a7e0743239f35f0b11af3fdfa"}
# 200
# {"object":"page","id":"85b421c6-733f-4d3f-87ed-a95b480c857d","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"b2c6945d-5214-4018-8ee2-f09b25447c8a","name":"Reading Discussions","color":"gray"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-21T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942232"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 8 Reading Discussion","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 8 Reading Discussion","href":null}]}},"url":"https://www.notion.so/Module-8-Reading-Discussion-85b421c6733f4d3f87eda95b480c857d"}
# 200
# {"object":"page","id":"fab84dc7-0fec-4d54-91f7-5252c3a223f7","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"b2c6945d-5214-4018-8ee2-f09b25447c8a","name":"Reading Discussions","color":"gray"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-28T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942235"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Module 9 Reading Discussion","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Module 9 Reading Discussion","href":null}]}},"url":"https://www.notion.so/Module-9-Reading-Discussion-fab84dc70fec4d5491f75252c3a223f7"}
# https://canvas.uw.edu/api/v1/courses/1516711/assignment_groups/1692139/assignments
# 200
# {"object":"page","id":"89f313d9-c3f9-4577-8460-0ec93f9c8e67","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"48855ca9-b3a5-41ea-914c-9739cd86a03f","name":"Projects","color":"default"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-06T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942722"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Analyze a Design","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Analyze a Design","href":null}]}},"url":"https://www.notion.so/Analyze-a-Design-89f313d9c3f9457784600ec93f9c8e67"}
# 200
# {"object":"page","id":"6300a3e2-f08c-43c8-96c0-4b8d5259e283","created_time":"2022-01-20T16:54:00.000Z","last_edited_time":"2022-01-20T16:54:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"48855ca9-b3a5-41ea-914c-9739cd86a03f","name":"Projects","color":"default"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-03-04T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942721"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Pitch a Design","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Pitch a Design","href":null}]}},"url":"https://www.notion.so/Pitch-a-Design-6300a3e2f08c43c896c04b8d5259e283"}
# 200
# {"object":"page","id":"33e72121-d23b-4790-a1d3-5d1c5e1933e7","created_time":"2022-01-20T16:55:00.000Z","last_edited_time":"2022-01-20T16:55:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"👽"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"48855ca9-b3a5-41ea-914c-9739cd86a03f","name":"Projects","color":"default"}},"Starting early":{"id":"Axm%3B","type":"checkbox","checkbox":false},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-03-15T23:59:00.000-07:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"select","select":{"id":"564ad136-c6ec-4811-8703-0650acf6e965","name":"Not Started","color":"purple"}},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1516711/assignments/6942718"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"9f10deba-e916-44fd-8866-b6c175551ee1","name":"INFO 200 Wi 2022","color":"orange"}},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Envision a Design","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Envision a Design","href":null}]}},"url":"https://www.notion.so/Envision-a-Design-33e72121d23b4790a1d35d1c5e1933e7"}
# 400
# {"object":"error","status":400,"code":"validation_error","message":"body failed validation: body.properties.Due Date.date.start should be a valid ISO 8601 date string, instead was `\"\"`."}
# 400
# {"object":"error","status":400,"code":"validation_error","message":"body failed validation: body.properties.Due Date.date.start should be a valid ISO 8601 date string, instead was `\"\"`."}
# https://canvas.uw.edu/api/v1/courses/1516711/assignment_groups/1694656/assignments
# 400
# {"object":"error","status":400,"code":"validation_error","message":"body failed validation: body.properties.Due Date.date.start should be a valid ISO 8601 date string, instead was `\"\"`."}
# 400
# {"object":"error","status":400,"code":"validation_error","message":"body failed validation: body.properties.Due Date.date.start should be a valid ISO 8601 date string, instead was `\"\"`."}
# 400
# {"object":"error","status":400,"code":"validation_error","message":"body failed validation: body.properties.Due Date.date.start should be a valid ISO 8601 date string, instead was `\"\"`."}
