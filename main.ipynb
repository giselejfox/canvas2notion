# %% [markdown]
# # Lets go babYYY!

# %%
# Import everything we need
import json
import requests
import datetime
import pytz
import secrets #contains the notion token, the notion database ID, and the canvas token.

# %%
# Have a list of all classes and their corresponding course ids so you can change what we're working
# with at the moment
course_ids = {
  "INFO 310": "1479924",
  "INFO 200": "1479903",
  "ENVIR 239": "1478724",
  "INFO 330": "1479933",
  "INFO 415": "1516805",
  "INFO 340": "1516756",
  "BIME 435": "1514384"
}

## have a list of all the emojis you want to attribute to each class
course_emojis = {
  "1479924": "🔐", #INFO 310 
  "1479903": "💛", #INFO 200
  "1478724": "♻️",  #ENVIR 239
  "1479933": "🗄",    #INFO 330
  "1516805": "🛡",   #INFO 415
  "1516756": "🕷", #INFO 340
  "1514384": "🏥" #BIME 435
}

# %%
# Chose the current course we're working with
current_course_name = input("Course: ")
current_course_id = course_ids[current_course_name]

# %%
# Create the necessary url and headers for notion
notion_base_url = "https://api.notion.com/v1/pages"
notion_headers = {
    "Authorization": "Bearer " + secrets.notion_token,
    "Content-Type": "application/json",
    "Notion-Version": "2021-08-16"
}

# Create the necessary url and headers for canvas
canvas_base = "https://canvas.uw.edu/api/v1/courses/"
canvas_assGr_URL = canvas_base + current_course_id + "/assignment_groups"
canvas_header = {
    "Authorization": "Bearer " + secrets.canvas_token
}

# %%
# Get the project groups from canvas
response = requests.get(canvas_assGr_URL, headers=canvas_header)

# Convert it into readable json format
proj_groups = response.json()

print(proj_groups)
# Out:
# [{'id': 1680252, 'name': 'Assignments', 'position': 1, 'group_weight': 35.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}, {'id': 1680253, 'name': 'Labs', 'position': 2, 'group_weight': 35.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}, {'id': 1680254, 'name': 'Final Project', 'position': 3, 'group_weight': 30.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}]

# %%
# NEED TO CHANGE THE COMPLETED PROPERTY TO STAGE (and the starting select option to "Not Started")



#  For each project group get all the assignments, clean up the data, and put it in a page
for i in range(0, len(proj_groups)):
    # get the id for the assignment group we're currently looking at
    assGrID = str(proj_groups[i]["id"])

    # make the URL to get the assignments in that group
    canvas_ass_URL = canvas_assGr_URL + "/" + assGrID + "/assignments"

    print(canvas_ass_URL)

    # get the assignments in that project group from canvas
    response = requests.get(canvas_ass_URL, headers=canvas_header)

    # Convert it into readable json format
    assignments = response.json()

    # For each assignment clean up the data and pop it into canvas
    for k in range(len(assignments)):

        # Pop off the assignment we need right now
        current = assignments[k]
        
        # Format part of the assignment URL we need to make it accessible as a UW student
        better_URL = current["html_url"].replace("https://canvas.instructure.com", "https://canvas.uw.edu")

        # Format the date to be equipped to timezone change
        if (current["due_at"] is None):
            better_date = ""
        else:
            # First make the assignment due date into a datetime object
            dt = datetime.datetime.strptime(current["due_at"], "%Y-%m-%dT%H:%M:%SZ")
            # Then make sure the timezone of the datetime object is UTC
            dt_UTC = pytz.utc.localize(dt)
            # Then switch the timezone to where you are
            dt_pst = dt_UTC.astimezone(pytz.timezone("America/Los_Angeles")) 
            # Then make sure the date we put into the page is in ISO format
            better_date = dt_pst.isoformat()

        # Create a new dictionary that will populate the new notion page of this assignment
        pageData = {
            "parent": { 
                "database_id": secrets.notion_database_id
            },
            "icon": {
                "type": "emoji",
                "emoji": course_emojis[current_course_id]
            },
            "properties": {
                "Title": {
                    "title": [
                        {
                            "text": {
                                "content": current["name"]
                            }
                        }
                    ]
                },
                "Class": {
                    "select": {
                        "name": current_course_name
                    }
                },
                "Due Date": {
                    "date": {
                        "start": better_date
                    }
                },
                "URL" : {
                    "url": better_URL
                },
                "Type": {
                    "select": {
                        "name": proj_groups[i]["name"]
                    }
                }
            }
        }

        # Convert the new dictionary pageData to json for sending
        data = json.dumps(pageData)

        # Send the new page out to notion
        res = requests.request("POST", notion_base_url, headers=notion_headers, data=data)

        # Troubleshoot helpers
        print(res.status_code)
        print(res.text)
# Out:
# https://canvas.uw.edu/api/v1/courses/1514384/assignment_groups/1680252/assignments
# 200
# {"object":"page","id":"0d86ee59-7529-447c-9ee3-318bec228339","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"55918c94-4d2b-4f0d-9432-171db4ade153","name":"Assignments","color":"brown"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-07T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886006"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Quiz 1","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Quiz 1","href":null}]}},"url":"https://www.notion.so/Quiz-1-0d86ee597529447c9ee3318bec228339"}
# 200
# {"object":"page","id":"0bb8e1a9-cd09-48dd-9eef-b9504333f6c8","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"55918c94-4d2b-4f0d-9432-171db4ade153","name":"Assignments","color":"brown"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-14T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886014"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Quiz 2","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Quiz 2","href":null}]}},"url":"https://www.notion.so/Quiz-2-0bb8e1a9cd0948dd9eefb9504333f6c8"}
# 200
# {"object":"page","id":"d436fede-ca64-4c15-a6ed-fbcc3242cb58","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"55918c94-4d2b-4f0d-9432-171db4ade153","name":"Assignments","color":"brown"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-21T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886010"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Quiz 3","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Quiz 3","href":null}]}},"url":"https://www.notion.so/Quiz-3-d436fedeca644c15a6edfbcc3242cb58"}
# 200
# {"object":"page","id":"7abcfaf7-fcc9-445c-ba6d-900282fbe530","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"55918c94-4d2b-4f0d-9432-171db4ade153","name":"Assignments","color":"brown"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-28T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886021"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Quiz 4","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Quiz 4","href":null}]}},"url":"https://www.notion.so/Quiz-4-7abcfaf7fcc9445cba6d900282fbe530"}
# 200
# {"object":"page","id":"7b263727-da96-4cc5-8c1a-a914da36fe86","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"55918c94-4d2b-4f0d-9432-171db4ade153","name":"Assignments","color":"brown"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-04T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886017"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Quiz 5","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Quiz 5","href":null}]}},"url":"https://www.notion.so/Quiz-5-7b263727da964cc58c1aa914da36fe86"}
# 200
# {"object":"page","id":"07b3a1db-2e27-4a87-a04e-7edf64a6873e","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"55918c94-4d2b-4f0d-9432-171db4ade153","name":"Assignments","color":"brown"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-11T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886024"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Quiz 6","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Quiz 6","href":null}]}},"url":"https://www.notion.so/Quiz-6-07b3a1db2e274a87a04e7edf64a6873e"}
# 200
# {"object":"page","id":"16dbe111-1f88-452d-9358-cff4f2432250","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"55918c94-4d2b-4f0d-9432-171db4ade153","name":"Assignments","color":"brown"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-18T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886026"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Quiz 7","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Quiz 7","href":null}]}},"url":"https://www.notion.so/Quiz-7-16dbe1111f88452d9358cff4f2432250"}
# 200
# {"object":"page","id":"aadbe41c-a51a-425b-983f-f5885514dcc6","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"55918c94-4d2b-4f0d-9432-171db4ade153","name":"Assignments","color":"brown"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-25T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886003"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Quiz 8","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Quiz 8","href":null}]}},"url":"https://www.notion.so/Quiz-8-aadbe41ca51a425b983ff5885514dcc6"}
# 200
# {"object":"page","id":"3a5a78f8-3a13-4c3d-96c1-753ec70f571a","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"55918c94-4d2b-4f0d-9432-171db4ade153","name":"Assignments","color":"brown"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-03-04T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886025"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Quiz 9","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Quiz 9","href":null}]}},"url":"https://www.notion.so/Quiz-9-3a5a78f83a134c3d96c1753ec70f571a"}
# 200
# {"object":"page","id":"493ada47-b4cb-435c-b4cf-5d2982f37c25","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"55918c94-4d2b-4f0d-9432-171db4ade153","name":"Assignments","color":"brown"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-07T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886030"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Reflection 1. Discussion: Getting to know you","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Reflection 1. Discussion: Getting to know you","href":null}]}},"url":"https://www.notion.so/Reflection-1-Discussion-Getting-to-know-you-493ada47b4cb435cb4cf5d2982f37c25"}
# https://canvas.uw.edu/api/v1/courses/1514384/assignment_groups/1680253/assignments
# 200
# {"object":"page","id":"3ff6d73c-3e33-4969-a7e5-e0918147d012","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-07T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886040"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Lab 1 (Week 1)","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Lab 1 (Week 1)","href":null}]}},"url":"https://www.notion.so/Lab-1-Week-1-3ff6d73c3e334969a7e5e0918147d012"}
# 200
# {"object":"page","id":"e8f1d230-b1eb-45c0-883f-3992eeb7b704","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-14T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886041"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Lab 2 (Week 2)","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Lab 2 (Week 2)","href":null}]}},"url":"https://www.notion.so/Lab-2-Week-2-e8f1d230b1eb45c0883f3992eeb7b704"}
# 200
# {"object":"page","id":"50ddb6f4-b89d-4020-9433-d43807393fdd","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-28T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886042"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Lab 3 (Week 4)","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Lab 3 (Week 4)","href":null}]}},"url":"https://www.notion.so/Lab-3-Week-4-50ddb6f4b89d40209433d43807393fdd"}
# 200
# {"object":"page","id":"5214b647-f392-422b-9e8d-6d486e9c46bb","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-04T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886043"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Lab 4 (Week 5)","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Lab 4 (Week 5)","href":null}]}},"url":"https://www.notion.so/Lab-4-Week-5-5214b647f392422b9e8d6d486e9c46bb"}
# 200
# {"object":"page","id":"71ff8a0b-e24f-4645-9a12-70c8b91e917d","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-11T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886044"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Lab 5 (Week 6) ","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Lab 5 (Week 6) ","href":null}]}},"url":"https://www.notion.so/Lab-5-Week-6-71ff8a0be24f46459a1270c8b91e917d"}
# 200
# {"object":"page","id":"c4975a88-9ccd-42b2-b04b-57a7a366ae74","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-18T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886045"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Lab 6 (Week 8)","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Lab 6 (Week 8)","href":null}]}},"url":"https://www.notion.so/Lab-6-Week-8-c4975a889ccd42b2b04b57a7a366ae74"}
# 200
# {"object":"page","id":"e58e2821-4f4c-4a5d-a345-f0a5f09bb5ff","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"83b1906a-7ae8-403b-8aba-6c29637f1cb2","name":"Labs","color":"pink"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-03-04T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6926731"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Lab 7 (Week 9)","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Lab 7 (Week 9)","href":null}]}},"url":"https://www.notion.so/Lab-7-Week-9-e58e28214f4c4a5da345f0a5f09bb5ff"}
# https://canvas.uw.edu/api/v1/courses/1514384/assignment_groups/1680254/assignments
# 400
# {"object":"error","status":400,"code":"validation_error","message":"body failed validation: body.properties.Due Date.date.start should be a valid ISO 8601 date string, instead was `\"\"`."}
# 200
# {"object":"page","id":"ef764bca-892b-4f7f-9241-34241f7a104c","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"0a0a2f73-6b55-4edf-b5cb-a8c0c704d3c1","name":"Final Project","color":"blue"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-21T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6941994"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Final Project Interests and Preferences","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Final Project Interests and Preferences","href":null}]}},"url":"https://www.notion.so/Final-Project-Interests-and-Preferences-ef764bca892b4f7f924134241f7a104c"}
# 200
# {"object":"page","id":"b079f772-169f-47f2-842e-c6cecb9b3ecb","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"0a0a2f73-6b55-4edf-b5cb-a8c0c704d3c1","name":"Final Project","color":"blue"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-01-28T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886038"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Final project team selection","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Final project team selection","href":null}]}},"url":"https://www.notion.so/Final-project-team-selection-b079f772169f47f2842ec6cecb9b3ecb"}
# 200
# {"object":"page","id":"5a3ed10a-2c6e-47e9-ae67-e0ebc125dca6","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"0a0a2f73-6b55-4edf-b5cb-a8c0c704d3c1","name":"Final Project","color":"blue"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-04T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886032"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Draft problem statement","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Draft problem statement","href":null}]}},"url":"https://www.notion.so/Draft-problem-statement-5a3ed10a2c6e47e9ae67e0ebc125dca6"}
# 200
# {"object":"page","id":"b0b2ed0b-e786-4e5e-a5da-640d9b6059e5","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"0a0a2f73-6b55-4edf-b5cb-a8c0c704d3c1","name":"Final Project","color":"blue"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-11T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886034"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Draft related work","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Draft related work","href":null}]}},"url":"https://www.notion.so/Draft-related-work-b0b2ed0be7864e5ea5da640d9b6059e5"}
# 200
# {"object":"page","id":"9d0fc3f0-5bd8-4a23-a088-570f515991c7","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"0a0a2f73-6b55-4edf-b5cb-a8c0c704d3c1","name":"Final Project","color":"blue"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-18T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886033"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Draft prototype","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Draft prototype","href":null}]}},"url":"https://www.notion.so/Draft-prototype-9d0fc3f05bd84a23a088570f515991c7"}
# 200
# {"object":"page","id":"8ed65e0b-f824-4da9-9810-d40472be8a16","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"0a0a2f73-6b55-4edf-b5cb-a8c0c704d3c1","name":"Final Project","color":"blue"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-02-25T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886031"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Complete draft report for peer review","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Complete draft report for peer review","href":null}]}},"url":"https://www.notion.so/Complete-draft-report-for-peer-review-8ed65e0bf8244da99810d40472be8a16"}
# 200
# {"object":"page","id":"9bbd8c2a-9abb-4075-b0a9-9e4db0141cba","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"0a0a2f73-6b55-4edf-b5cb-a8c0c704d3c1","name":"Final Project","color":"blue"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-03-04T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886046"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Peer review","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Peer review","href":null}]}},"url":"https://www.notion.so/Peer-review-9bbd8c2a9abb4075b0a99e4db0141cba"}
# 200
# {"object":"page","id":"2dada49b-8cad-4360-8320-7d6c89bcc63c","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"0a0a2f73-6b55-4edf-b5cb-a8c0c704d3c1","name":"Final Project","color":"blue"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-03-06T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886036"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Final project presentation","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Final project presentation","href":null}]}},"url":"https://www.notion.so/Final-project-presentation-2dada49b8cad436083207d6c89bcc63c"}
# 200
# {"object":"page","id":"c3122e6e-59c1-40b9-b2f5-7ec9ec758a93","created_time":"2022-01-02T04:56:00.000Z","last_edited_time":"2022-01-02T04:56:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"🏥"},"parent":{"type":"database_id","database_id":"28564d15-3ffd-40a6-92f3-d96eeb5035b2"},"archived":false,"properties":{"Type":{"id":"%3BrqM","type":"select","select":{"id":"0a0a2f73-6b55-4edf-b5cb-a8c0c704d3c1","name":"Final Project","color":"blue"}},"Related to Weekly (Property)":{"id":"Pwn%3D","type":"relation","relation":[]},"Due Date":{"id":"d%5BWF","type":"date","date":{"start":"2022-03-11T23:59:00.000-08:00","end":null,"time_zone":null}},"Completed":{"id":"fAi%7B","type":"checkbox","checkbox":false},"URL":{"id":"tfd%3B","type":"url","url":"https://canvas.uw.edu/courses/1514384/assignments/6886037"},"Class":{"id":"xf%7Bv","type":"select","select":{"id":"f6a8417d-5bba-4357-ba19-6e524d2081b7","name":"BIME 435","color":"pink"}},"Due on Day":{"id":"x%7BgA","type":"select","select":null},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Final project report","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Final project report","href":null}]}},"url":"https://www.notion.so/Final-project-report-c3122e6e59c140b9b2f57ec9ec758a93"}
