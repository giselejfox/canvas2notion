# %% [markdown]
# # Lets go babYYY!

# %%
# Import everything we need
import json
import requests
import datetime
import pytz
import secrets_leary #contains the notion token, the notion database ID, and the canvas token.

# %%
# Have a list of all classes and their corresponding course ids so you can change what we're working
# with at the moment
course_ids = {
  "INFO 310": "1479924",
  "INFO 200": "1479903",
  "ENVIR 239": "1478724",
  "INFO 330": "1479933",
  "INFO 415": "1516805",
  "INFO 340": "1516756",
  "BIME 435": "1514384",
  "INFO 200 Wi 2022": "1516711", #Wi 2022
  "CEP 491": "1514758" # Leary's class
}

## have a list of all the emojis you want to attribute to each class
course_emojis = {
  "1479924": "🔐", #INFO 310 
  "1479903": "💛", #INFO 200
  "1478724": "♻️",  #ENVIR 239
  "1479933": "🗄",    #INFO 330
  "1516805": "🛡",   #INFO 415
  "1516756": "🕷", #INFO 340
  "1514384": "🏥", #BIME 435
  "1516711": "👽", #INFO 200 Wi 2022
  "1514758": "⚫" # CEP 491
}

# %%
# Chose the current course we're working with
current_course_name = input("Course: ")
current_course_id = course_ids[current_course_name]

# %%
# Create the necessary url and headers for notion
notion_base_url = "https://api.notion.com/v1/pages"
notion_headers = {
    "Authorization": "Bearer " + secrets_leary.notion_token,
    "Content-Type": "application/json",
    "Notion-Version": "2021-08-16"
}

# Create the necessary url and headers for canvas
canvas_base = "https://canvas.uw.edu/api/v1/courses/"
canvas_assGr_URL = canvas_base + current_course_id + "/assignment_groups"
canvas_header = {
    "Authorization": "Bearer " + secrets_leary.canvas_token
}

# %%
# Get the project groups from canvas
response = requests.get(canvas_assGr_URL, headers=canvas_header)

# Convert it into readable json format
proj_groups = response.json()

print(proj_groups)
# Out:
# [{'id': 1693622, 'name': 'Individual Check-in', 'position': 1, 'group_weight': 0.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}, {'id': 1693623, 'name': 'In-Class Participation', 'position': 2, 'group_weight': 0.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}, {'id': 1693624, 'name': 'Weekly Status Reports', 'position': 3, 'group_weight': 0.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}, {'id': 1693625, 'name': 'Tasks', 'position': 4, 'group_weight': 0.0, 'sis_source_id': None, 'integration_data': {}, 'rules': {}}]

# %%
#  For each project group get all the assignments, clean up the data, and put it in a page
for i in range(0, len(proj_groups)):
    # get the id for the assignment group we're currently looking at
    assGrID = str(proj_groups[i]["id"])

    # make the URL to get the assignments in that group
    canvas_ass_URL = canvas_assGr_URL + "/" + assGrID + "/assignments"

    print(canvas_ass_URL)

    # get the assignments in that project group from canvas
    response = requests.get(canvas_ass_URL, headers=canvas_header)

    # Convert it into readable json format
    assignments = response.json()

    # For each assignment clean up the data and pop it into canvas
    for k in range(len(assignments)):

        # Pop off the assignment we need right now
        current = assignments[k]
        
        # Format part of the assignment URL we need to make it accessible as a UW student
        better_URL = current["html_url"].replace("https://canvas.instructure.com", "https://canvas.uw.edu")

        # Format the date to be equipped to timezone change
        if (current["due_at"] is None):
            better_date = ""
        else:
            # First make the assignment due date into a datetime object
            dt = datetime.datetime.strptime(current["due_at"], "%Y-%m-%dT%H:%M:%SZ")
            # Then make sure the timezone of the datetime object is UTC
            dt_UTC = pytz.utc.localize(dt)
            # Then switch the timezone to where you are
            dt_pst = dt_UTC.astimezone(pytz.timezone("America/Los_Angeles")) 
            # Then make sure the date we put into the page is in ISO format
            better_date = dt_pst.isoformat()

        # Create a new dictionary that will populate the new notion page of this assignment
        pageData = {
            "parent": { 
                "database_id": secrets_leary.notion_database_id
            },
            "icon": {
                "type": "emoji",
                "emoji": course_emojis[current_course_id]
            },
            "properties": {
                "Title": {
                    "title": [
                        {
                            "text": {
                                "content": current["name"]
                            }
                        }
                    ]
                },
                "Class": {
                    "select": {
                        "name": current_course_name
                    }
                },
                "Due Date": {
                    "date": {
                        "start": better_date
                    }
                },
                "URL" : {
                    "url": better_URL
                },
                "Type": {
                    "select": {
                        "name": proj_groups[i]["name"]
                    }
                },
                "Completed" : {
                    "select": {
                        "name": "Not Started"
                    }
                },
                "Starting early": {
                    "checkbox": False
                }
            }
        }

        # Convert the new dictionary pageData to json for sending
        data = json.dumps(pageData)

        # Send the new page out to notion
        res = requests.request("POST", notion_base_url, headers=notion_headers, data=data)

        # Troubleshoot helpers
        print(res.status_code)
        print(res.text)
# Out:
# https://canvas.uw.edu/api/v1/courses/1514758/assignment_groups/1693622/assignments
# 200
# {"object":"page","id":"2195e40f-6ee7-43f4-a622-72c0ded75f3d","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-03-09T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"04eab7f9-2d16-4879-b7e4-87fb2025c061","name":"Individual Check-in","color":"yellow"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948660"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Individual Check-in","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Individual Check-in","href":null}]}},"url":"https://www.notion.so/Individual-Check-in-2195e40f6ee743f4a62272c0ded75f3d"}
# https://canvas.uw.edu/api/v1/courses/1514758/assignment_groups/1693623/assignments
# 200
# {"object":"page","id":"f16c0393-9148-47e6-adf3-5a502101d092","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-01-05T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"184fac64-c846-4264-8551-759c9a1d950f","name":"In-Class Participation","color":"default"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948673"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 1: In-Class Participation","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 1: In-Class Participation","href":null}]}},"url":"https://www.notion.so/Week-1-In-Class-Participation-f16c0393914847e6adf35a502101d092"}
# 200
# {"object":"page","id":"8d6c73fc-8acc-4ac8-a314-3ec1425f8927","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-01-12T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"184fac64-c846-4264-8551-759c9a1d950f","name":"In-Class Participation","color":"default"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948674"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 2: In-Class Participation","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 2: In-Class Participation","href":null}]}},"url":"https://www.notion.so/Week-2-In-Class-Participation-8d6c73fc8acc4ac8a3143ec1425f8927"}
# 200
# {"object":"page","id":"a562d92d-7d4c-4eeb-86c5-5cb60095b7b8","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-01-19T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"184fac64-c846-4264-8551-759c9a1d950f","name":"In-Class Participation","color":"default"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948676"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 3: Work Day (No Class)","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 3: Work Day (No Class)","href":null}]}},"url":"https://www.notion.so/Week-3-Work-Day-No-Class-a562d92d7d4c4eeb86c55cb60095b7b8"}
# 200
# {"object":"page","id":"0c6fb2ea-0d4f-4e6d-82db-f80cfedf356e","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-01-26T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"184fac64-c846-4264-8551-759c9a1d950f","name":"In-Class Participation","color":"default"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948678"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 4: In-Class Participation","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 4: In-Class Participation","href":null}]}},"url":"https://www.notion.so/Week-4-In-Class-Participation-0c6fb2ea0d4f4e6d82dbf80cfedf356e"}
# 200
# {"object":"page","id":"ded86596-f19b-4909-9b37-25e339da9142","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-02T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"184fac64-c846-4264-8551-759c9a1d950f","name":"In-Class Participation","color":"default"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948680"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 5: In-Class Participation","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 5: In-Class Participation","href":null}]}},"url":"https://www.notion.so/Week-5-In-Class-Participation-ded86596f19b49099b3725e339da9142"}
# 200
# {"object":"page","id":"d05651a4-8048-443b-ac1a-7551b2c0317b","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-09T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"184fac64-c846-4264-8551-759c9a1d950f","name":"In-Class Participation","color":"default"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948682"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 6: Work Day (No Class)","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 6: Work Day (No Class)","href":null}]}},"url":"https://www.notion.so/Week-6-Work-Day-No-Class-d05651a48048443bac1a7551b2c0317b"}
# 200
# {"object":"page","id":"abc6da6d-28b3-4988-8280-02106f99c1c3","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-16T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"184fac64-c846-4264-8551-759c9a1d950f","name":"In-Class Participation","color":"default"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948684"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 7: In-Class Participation","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 7: In-Class Participation","href":null}]}},"url":"https://www.notion.so/Week-7-In-Class-Participation-abc6da6d28b34988828002106f99c1c3"}
# 200
# {"object":"page","id":"ddc93bfd-0275-478a-9a30-586949c5781c","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-23T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"184fac64-c846-4264-8551-759c9a1d950f","name":"In-Class Participation","color":"default"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948686"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 8: In-Class Participation","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 8: In-Class Participation","href":null}]}},"url":"https://www.notion.so/Week-8-In-Class-Participation-ddc93bfd0275478a9a30586949c5781c"}
# 200
# {"object":"page","id":"82dfda42-18c8-461c-9344-894e92ff55bb","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-03-02T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"184fac64-c846-4264-8551-759c9a1d950f","name":"In-Class Participation","color":"default"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948688"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 9: In-Class Participation","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 9: In-Class Participation","href":null}]}},"url":"https://www.notion.so/Week-9-In-Class-Participation-82dfda4218c8461c9344894e92ff55bb"}
# 200
# {"object":"page","id":"6a545f49-272a-4428-8814-30df506c631f","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-03-09T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"184fac64-c846-4264-8551-759c9a1d950f","name":"In-Class Participation","color":"default"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948672"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 10: In-Class Participation","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 10: In-Class Participation","href":null}]}},"url":"https://www.notion.so/Week-10-In-Class-Participation-6a545f49272a4428881430df506c631f"}
# https://canvas.uw.edu/api/v1/courses/1514758/assignment_groups/1693624/assignments
# 200
# {"object":"page","id":"78b987e7-3652-4b30-99ad-11190ea91a82","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-01-19T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"4cfc0a0c-bb93-4602-b513-d72ecef87d5e","name":"Weekly Status Reports","color":"gray"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948675"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 2: Status Report","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 2: Status Report","href":null}]}},"url":"https://www.notion.so/Week-2-Status-Report-78b987e736524b3099ad11190ea91a82"}
# 200
# {"object":"page","id":"085302bf-00ec-45ef-b771-9bb56ae25464","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-01-26T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"4cfc0a0c-bb93-4602-b513-d72ecef87d5e","name":"Weekly Status Reports","color":"gray"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948677"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 3: Status Report","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 3: Status Report","href":null}]}},"url":"https://www.notion.so/Week-3-Status-Report-085302bf00ec45efb7719bb56ae25464"}
# 200
# {"object":"page","id":"7221a9b4-76ef-4e11-a3d7-a074d5861b0a","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-02T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"4cfc0a0c-bb93-4602-b513-d72ecef87d5e","name":"Weekly Status Reports","color":"gray"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948679"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 4: Status Report","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 4: Status Report","href":null}]}},"url":"https://www.notion.so/Week-4-Status-Report-7221a9b476ef4e11a3d7a074d5861b0a"}
# 200
# {"object":"page","id":"c59bc1ad-4b6d-4004-8230-591a57fa6807","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-09T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"4cfc0a0c-bb93-4602-b513-d72ecef87d5e","name":"Weekly Status Reports","color":"gray"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948681"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 5: Status Report","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 5: Status Report","href":null}]}},"url":"https://www.notion.so/Week-5-Status-Report-c59bc1ad4b6d40048230591a57fa6807"}
# 200
# {"object":"page","id":"af9f922f-08ee-4bfe-9de0-2462934b122c","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-16T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"4cfc0a0c-bb93-4602-b513-d72ecef87d5e","name":"Weekly Status Reports","color":"gray"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948683"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 6: Status Report","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 6: Status Report","href":null}]}},"url":"https://www.notion.so/Week-6-Status-Report-af9f922f08ee4bfe9de02462934b122c"}
# 200
# {"object":"page","id":"09fc7bb2-d8b0-454d-8246-5981950f743f","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-23T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"4cfc0a0c-bb93-4602-b513-d72ecef87d5e","name":"Weekly Status Reports","color":"gray"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948685"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 7: Status Report","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 7: Status Report","href":null}]}},"url":"https://www.notion.so/Week-7-Status-Report-09fc7bb2d8b0454d82465981950f743f"}
# 200
# {"object":"page","id":"325be5e0-6fac-4831-ba57-bcf9954285cb","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-03-02T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"4cfc0a0c-bb93-4602-b513-d72ecef87d5e","name":"Weekly Status Reports","color":"gray"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948687"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 8: Status Report","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 8: Status Report","href":null}]}},"url":"https://www.notion.so/Week-8-Status-Report-325be5e06fac4831ba57bcf9954285cb"}
# 200
# {"object":"page","id":"02744b9d-df12-4ef6-859d-f82c49362812","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-03-09T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"4cfc0a0c-bb93-4602-b513-d72ecef87d5e","name":"Weekly Status Reports","color":"gray"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948689"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Week 9: Status Report","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Week 9: Status Report","href":null}]}},"url":"https://www.notion.so/Week-9-Status-Report-02744b9ddf124ef6859df82c49362812"}
# https://canvas.uw.edu/api/v1/courses/1514758/assignment_groups/1693625/assignments
# 200
# {"object":"page","id":"5b23d00e-aaa5-4b71-bc3c-1557848519aa","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-01-12T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"b9b165e8-6abf-4390-bb58-7eab024b26a0","name":"Tasks","color":"blue"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948661"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Task 1: Work Plan","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Task 1: Work Plan","href":null}]}},"url":"https://www.notion.so/Task-1-Work-Plan-5b23d00eaaa54b71bc3c1557848519aa"}
# 200
# {"object":"page","id":"6743c5b2-8a30-4c38-b207-b3529e6eab66","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-01-19T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"b9b165e8-6abf-4390-bb58-7eab024b26a0","name":"Tasks","color":"blue"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948663"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Task 2: Literature Review Outline","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Task 2: Literature Review Outline","href":null}]}},"url":"https://www.notion.so/Task-2-Literature-Review-Outline-6743c5b28a304c38b207b3529e6eab66"}
# 200
# {"object":"page","id":"ba2762cf-4fe6-4a95-9e13-5250e7d520b6","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-02T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"b9b165e8-6abf-4390-bb58-7eab024b26a0","name":"Tasks","color":"blue"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948664"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Task 3A: Literature Review Part I","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Task 3A: Literature Review Part I","href":null}]}},"url":"https://www.notion.so/Task-3A-Literature-Review-Part-I-ba2762cf4fe64a959e135250e7d520b6"}
# 200
# {"object":"page","id":"013bb88a-2791-4501-a0c5-e83acc96ca5d","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-16T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"b9b165e8-6abf-4390-bb58-7eab024b26a0","name":"Tasks","color":"blue"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948665"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Task 3B: Literature Review Part II","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Task 3B: Literature Review Part II","href":null}]}},"url":"https://www.notion.so/Task-3B-Literature-Review-Part-II-013bb88a27914501a0c5e83acc96ca5d"}
# 200
# {"object":"page","id":"8d135320-5350-4698-b2c5-d26518b468d2","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-23T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"b9b165e8-6abf-4390-bb58-7eab024b26a0","name":"Tasks","color":"blue"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948666"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Task 4: Abstract","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Task 4: Abstract","href":null}]}},"url":"https://www.notion.so/Task-4-Abstract-8d13532053504698b2c5d26518b468d2"}
# 200
# {"object":"page","id":"55c5e9c8-fa59-4345-a269-f56d13f1cdb2","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-02-23T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"b9b165e8-6abf-4390-bb58-7eab024b26a0","name":"Tasks","color":"blue"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948667"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Task 5: Mentor Contract","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Task 5: Mentor Contract","href":null}]}},"url":"https://www.notion.so/Task-5-Mentor-Contract-55c5e9c8fa594345a269f56d13f1cdb2"}
# 200
# {"object":"page","id":"42a820cf-2a14-45ff-b2b5-b0991ddda5f5","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-03-02T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"b9b165e8-6abf-4390-bb58-7eab024b26a0","name":"Tasks","color":"blue"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948668"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Task 6A: 6-in-5 Slides ","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Task 6A: 6-in-5 Slides ","href":null}]}},"url":"https://www.notion.so/Task-6A-6-in-5-Slides-42a820cf2a1445ffb2b5b0991ddda5f5"}
# 200
# {"object":"page","id":"882e8f48-027f-4fe5-bc81-e3199a7f2284","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-03-02T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"b9b165e8-6abf-4390-bb58-7eab024b26a0","name":"Tasks","color":"blue"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948669"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Task 6B: 6-in-5 Practice Presentation (In Class)","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Task 6B: 6-in-5 Practice Presentation (In Class)","href":null}]}},"url":"https://www.notion.so/Task-6B-6-in-5-Practice-Presentation-In-Class-882e8f48027f4fe5bc81e3199a7f2284"}
# 200
# {"object":"page","id":"6ed06446-15be-4916-af82-c131e0284589","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-03-09T13:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"b9b165e8-6abf-4390-bb58-7eab024b26a0","name":"Tasks","color":"blue"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948670"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Task 7: Methodology ","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Task 7: Methodology ","href":null}]}},"url":"https://www.notion.so/Task-7-Methodology-6ed0644615be4916af82c131e0284589"}
# 200
# {"object":"page","id":"ccdc2e06-f187-4c6e-a4ba-587250202970","created_time":"2022-02-03T22:06:00.000Z","last_edited_time":"2022-02-03T22:06:00.000Z","cover":null,"icon":{"type":"emoji","emoji":"⚫"},"parent":{"type":"database_id","database_id":"3638be3c-2112-440d-ae8d-acfa51a65735"},"archived":false,"properties":{"Completed":{"id":"LKEN","type":"select","select":{"id":"d7355ecd-bfc9-4d53-af2b-ce7494f7e8f1","name":"Not Started","color":"brown"}},"Due Date":{"id":"QSQs","type":"date","date":{"start":"2022-03-11T08:30:00.000-08:00","end":null,"time_zone":null}},"Starting early":{"id":"%5B%3ESb","type":"checkbox","checkbox":false},"Class":{"id":"_DvG","type":"select","select":{"id":"ad57cb78-9d22-4119-8be7-30e70584ae04","name":"CEP 491","color":"red"}},"Type":{"id":"ongE","type":"select","select":{"id":"b9b165e8-6abf-4390-bb58-7eab024b26a0","name":"Tasks","color":"blue"}},"URL":{"id":"xiLI","type":"url","url":"https://canvas.uw.edu/courses/1514758/assignments/6948671"},"Title":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"Task 8: 6-in-5 Final Presentation (In Governance) ","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Task 8: 6-in-5 Final Presentation (In Governance) ","href":null}]}},"url":"https://www.notion.so/Task-8-6-in-5-Final-Presentation-In-Governance-ccdc2e06f1874c6ea4ba587250202970"}
